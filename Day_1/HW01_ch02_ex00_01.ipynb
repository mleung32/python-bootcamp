# %% [markdown]
# # HW01_ch02_ex00_01
# See section 2.4
# (1) Type the following statements in the Python interpreter to see what they do:
#     5
#     x = 5
#     x + 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (2) Now put the same statements into a script [this script] and run it. What is the output? [copy and past output here]

# %%
5
x = 5
x + 1
# Out:
# 6

# %% [markdown]
# (3) Modify the script above by transforming each expression into a print statement and then run it again.What is the output? [copy and past output here]

# %%
print(5)

x = 5
print(x)

print(f"{x + 1}")
# Out:
# 5
# 5
# 6
